# %%
import requests
import json
from pprint import pprint
STATIONS_URI = "https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey=aea147d4dfff79b378a54327d657aa5240ae2cd6"
r = requests.get(STATIONS_URI)
pprint(json.loads(r.text))
# Out:
# [{'address': 'Smithfield North',
#   'available_bike_stands': 15,
#   'available_bikes': 15,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680098000,
#   'name': 'SMITHFIELD NORTH',
#   'number': 42,
#   'position': {'lat': 53.349562, 'lng': -6.278198},
#   'status': 'OPEN'},
#  {'address': 'Parnell Square North',
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680245000,
#   'name': 'PARNELL SQUARE NORTH',
#   'number': 30,
#   'position': {'lat': 53.353462, 'lng': -6.265305},
#   'status': 'OPEN'},
#  {'address': 'Clonmel Street',
#   'available_bike_stands': 26,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 33,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680097000,
#   'name': 'CLONMEL STREET',
#   'number': 54,
#   'position': {'lat': 53.336021, 'lng': -6.26298},
#   'status': 'OPEN'},
#  {'address': 'Avondale Road',
#   'available_bike_stands': 37,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680223000,
#   'name': 'AVONDALE ROAD',
#   'number': 108,
#   'position': {'lat': 53.359405, 'lng': -6.276142},
#   'status': 'OPEN'},
#  {'address': 'Mount Street Lower',
#   'available_bike_stands': 17,
#   'available_bikes': 23,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680248000,
#   'name': 'MOUNT STREET LOWER',
#   'number': 56,
#   'position': {'lat': 53.33796, 'lng': -6.24153},
#   'status': 'OPEN'},
#  {'address': 'Christchurch Place',
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680100000,
#   'name': 'CHRISTCHURCH PLACE',
#   'number': 6,
#   'position': {'lat': 53.343368, 'lng': -6.27012},
#   'status': 'OPEN'},
#  {'address': 'Grantham Street',
#   'available_bike_stands': 22,
#   'available_bikes': 8,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679980000,
#   'name': 'GRANTHAM STREET',
#   'number': 18,
#   'position': {'lat': 53.334123, 'lng': -6.265436},
#   'status': 'OPEN'},
#  {'address': 'Pearse Street',
#   'available_bike_stands': 21,
#   'available_bikes': 9,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679885000,
#   'name': 'PEARSE STREET',
#   'number': 32,
#   'position': {'lat': 53.344304, 'lng': -6.250427},
#   'status': 'OPEN'},
#  {'address': 'York Street East',
#   'available_bike_stands': 13,
#   'available_bikes': 19,
#   'banking': False,
#   'bike_stands': 32,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680031000,
#   'name': 'YORK STREET EAST',
#   'number': 52,
#   'position': {'lat': 53.338755, 'lng': -6.262003},
#   'status': 'OPEN'},
#  {'address': 'Excise Walk',
#   'available_bike_stands': 9,
#   'available_bikes': 31,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680122000,
#   'name': 'EXCISE WALK',
#   'number': 48,
#   'position': {'lat': 53.347777, 'lng': -6.244239},
#   'status': 'OPEN'},
#  {'address': 'Fitzwilliam Square West',
#   'available_bike_stands': 15,
#   'available_bikes': 15,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680186000,
#   'name': 'FITZWILLIAM SQUARE WEST',
#   'number': 13,
#   'position': {'lat': 53.336074, 'lng': -6.252825},
#   'status': 'OPEN'},
#  {'address': 'Portobello Road',
#   'available_bike_stands': 25,
#   'available_bikes': 5,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679750000,
#   'name': 'PORTOBELLO ROAD',
#   'number': 43,
#   'position': {'lat': 53.330091, 'lng': -6.268044},
#   'status': 'OPEN'},
#  {'address': 'St. James Hospital (Central)',
#   'available_bike_stands': 32,
#   'available_bikes': 8,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680055000,
#   'name': 'ST. JAMES HOSPITAL (CENTRAL)',
#   'number': 81,
#   'position': {'lat': 53.339983, 'lng': -6.295594},
#   'status': 'OPEN'},
#  {'address': 'Parnell Street',
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680104000,
#   'name': 'PARNELL STREET',
#   'number': 31,
#   'position': {'lat': 53.350929, 'lng': -6.265125},
#   'status': 'OPEN'},
#  {'address': 'Frederick Street South',
#   'available_bike_stands': 20,
#   'available_bikes': 20,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679700000,
#   'name': 'FREDERICK STREET SOUTH',
#   'number': 98,
#   'position': {'lat': 53.341515, 'lng': -6.256853},
#   'status': 'OPEN'},
#  {'address': 'Fownes Street Upper',
#   'available_bike_stands': 24,
#   'available_bikes': 6,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680091000,
#   'name': 'FOWNES STREET UPPER',
#   'number': 14,
#   'position': {'lat': 53.344603, 'lng': -6.263371},
#   'status': 'OPEN'},
#  {'address': 'Custom House',
#   'available_bike_stands': 16,
#   'available_bikes': 14,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680195000,
#   'name': 'CUSTOM HOUSE',
#   'number': 23,
#   'position': {'lat': 53.348279, 'lng': -6.254662},
#   'status': 'OPEN'},
#  {'address': 'Rathdown Road',
#   'available_bike_stands': 34,
#   'available_bikes': 6,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679993000,
#   'name': 'RATHDOWN ROAD',
#   'number': 106,
#   'position': {'lat': 53.35893, 'lng': -6.280337},
#   'status': 'OPEN'},
#  {'address': "North Circular Road (O'Connell's)",
#   'available_bike_stands': 18,
#   'available_bikes': 12,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680255000,
#   'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)",
#   'number': 112,
#   'position': {'lat': 53.357841, 'lng': -6.251557},
#   'status': 'OPEN'},
#  {'address': 'Hanover Quay',
#   'available_bike_stands': 2,
#   'available_bikes': 38,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680144000,
#   'name': 'HANOVER QUAY',
#   'number': 68,
#   'position': {'lat': 53.344115, 'lng': -6.237153},
#   'status': 'OPEN'},
#  {'address': 'Oliver Bond Street',
#   'available_bike_stands': 17,
#   'available_bikes': 13,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680261000,
#   'name': 'OLIVER BOND STREET',
#   'number': 74,
#   'position': {'lat': 53.343893, 'lng': -6.280531},
#   'status': 'OPEN'},
#  {'address': 'Collins Barracks Museum',
#   'available_bike_stands': 30,
#   'available_bikes': 8,
#   'banking': True,
#   'bike_stands': 38,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680003000,
#   'name': 'COLLINS BARRACKS MUSEUM',
#   'number': 87,
#   'position': {'lat': 53.347477, 'lng': -6.28525},
#   'status': 'OPEN'},
#  {'address': 'Brookfield Road',
#   'available_bike_stands': 28,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679707000,
#   'name': 'BROOKFIELD ROAD',
#   'number': 84,
#   'position': {'lat': 53.339005, 'lng': -6.300217},
#   'status': 'OPEN'},
#  {'address': 'Benson Street',
#   'available_bike_stands': 9,
#   'available_bikes': 31,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680255000,
#   'name': 'BENSON STREET',
#   'number': 90,
#   'position': {'lat': 53.344153, 'lng': -6.233451},
#   'status': 'OPEN'},
#  {'address': 'Earlsfort Terrace',
#   'available_bike_stands': 16,
#   'available_bikes': 14,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680249000,
#   'name': 'EARLSFORT TERRACE',
#   'number': 11,
#   'position': {'lat': 53.334019, 'lng': -6.258371},
#   'status': 'OPEN'},
#  {'address': 'Golden Lane',
#   'available_bike_stands': 16,
#   'available_bikes': 4,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680014000,
#   'name': 'GOLDEN LANE',
#   'number': 17,
#   'position': {'lat': 53.340803, 'lng': -6.267732},
#   'status': 'OPEN'},
#  {'address': 'Deverell Place',
#   'available_bike_stands': 20,
#   'available_bikes': 10,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680250000,
#   'name': 'DEVERELL PLACE',
#   'number': 45,
#   'position': {'lat': 53.351464, 'lng': -6.255265},
#   'status': 'OPEN'},
#  {'address': 'Wilton Terrace (Park)',
#   'available_bike_stands': 24,
#   'available_bikes': 16,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680258000,
#   'name': 'WILTON TERRACE (PARK)',
#   'number': 114,
#   'position': {'lat': 53.333653, 'lng': -6.248345},
#   'status': 'OPEN'},
#  {'address': 'John Street West',
#   'available_bike_stands': 28,
#   'available_bikes': 3,
#   'banking': False,
#   'bike_stands': 31,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680217000,
#   'name': 'JOHN STREET WEST',
#   'number': 72,
#   'position': {'lat': 53.343105, 'lng': -6.277167},
#   'status': 'OPEN'},
#  {'address': 'Fenian Street',
#   'available_bike_stands': 12,
#   'available_bikes': 23,
#   'banking': False,
#   'bike_stands': 35,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680209000,
#   'name': 'FENIAN STREET',
#   'number': 63,
#   'position': {'lat': 53.341428, 'lng': -6.24672},
#   'status': 'OPEN'},
#  {'address': 'Merrion Square South',
#   'available_bike_stands': 14,
#   'available_bikes': 26,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680256000,
#   'name': 'MERRION SQUARE SOUTH',
#   'number': 113,
#   'position': {'lat': 53.338614, 'lng': -6.248606},
#   'status': 'OPEN'},
#  {'address': 'South Dock Road',
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680159000,
#   'name': 'SOUTH DOCK ROAD',
#   'number': 91,
#   'position': {'lat': 53.341833, 'lng': -6.231291},
#   'status': 'OPEN'},
#  {'address': 'City Quay',
#   'available_bike_stands': 11,
#   'available_bikes': 19,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679932000,
#   'name': 'CITY QUAY',
#   'number': 99,
#   'position': {'lat': 53.346637, 'lng': -6.246154},
#   'status': 'OPEN'},
#  {'address': 'Exchequer Street',
#   'available_bike_stands': 21,
#   'available_bikes': 3,
#   'banking': False,
#   'bike_stands': 24,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680253000,
#   'name': 'EXCHEQUER STREET',
#   'number': 9,
#   'position': {'lat': 53.343034, 'lng': -6.263578},
#   'status': 'OPEN'},
#  {'address': 'The Point',
#   'available_bike_stands': 3,
#   'available_bikes': 37,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680170000,
#   'name': 'THE POINT',
#   'number': 67,
#   'position': {'lat': 53.346867, 'lng': -6.230852},
#   'status': 'OPEN'},
#  {'address': 'Hatch Street',
#   'available_bike_stands': 26,
#   'available_bikes': 10,
#   'banking': False,
#   'bike_stands': 36,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680013000,
#   'name': 'HATCH STREET',
#   'number': 55,
#   'position': {'lat': 53.33403, 'lng': -6.260714},
#   'status': 'OPEN'},
#  {'address': 'Lime Street',
#   'available_bike_stands': 33,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680259000,
#   'name': 'LIME STREET',
#   'number': 62,
#   'position': {'lat': 53.346026, 'lng': -6.243576},
#   'status': 'OPEN'},
#  {'address': 'Charlemont Street',
#   'available_bike_stands': 25,
#   'available_bikes': 15,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680244000,
#   'name': 'CHARLEMONT PLACE',
#   'number': 5,
#   'position': {'lat': 53.330662, 'lng': -6.260177},
#   'status': 'OPEN'},
#  {'address': 'Kilmainham Gaol',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680201000,
#   'name': 'KILMAINHAM GAOL',
#   'number': 97,
#   'position': {'lat': 53.342113, 'lng': -6.310015},
#   'status': 'OPEN'},
#  {'address': 'Hardwicke Place',
#   'available_bike_stands': 25,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 25,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680149000,
#   'name': 'HARDWICKE PLACE',
#   'number': 61,
#   'position': {'lat': 53.357043, 'lng': -6.263232},
#   'status': 'OPEN'},
#  {'address': 'Wolfe Tone Street',
#   'available_bike_stands': 26,
#   'available_bikes': 3,
#   'banking': False,
#   'bike_stands': 29,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680214000,
#   'name': 'WOLFE TONE STREET',
#   'number': 77,
#   'position': {'lat': 53.348875, 'lng': -6.267459},
#   'status': 'OPEN'},
#  {'address': 'Francis Street',
#   'available_bike_stands': 24,
#   'available_bikes': 6,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680036000,
#   'name': 'FRANCIS STREET',
#   'number': 73,
#   'position': {'lat': 53.342081, 'lng': -6.275233},
#   'status': 'OPEN'},
#  {'address': 'Greek Street',
#   'available_bike_stands': 7,
#   'available_bikes': 13,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680217000,
#   'name': 'GREEK STREET',
#   'number': 4,
#   'position': {'lat': 53.346874, 'lng': -6.272976},
#   'status': 'OPEN'},
#  {'address': 'Guild Street',
#   'available_bike_stands': 2,
#   'available_bikes': 38,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680258000,
#   'name': 'GUILD STREET',
#   'number': 49,
#   'position': {'lat': 53.347932, 'lng': -6.240928},
#   'status': 'OPEN'},
#  {'address': 'Herbert Place',
#   'available_bike_stands': 21,
#   'available_bikes': 9,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680252000,
#   'name': 'HERBERT PLACE',
#   'number': 19,
#   'position': {'lat': 53.334432, 'lng': -6.245575},
#   'status': 'OPEN'},
#  {'address': 'High Street',
#   'available_bike_stands': 27,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 29,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680160000,
#   'name': 'HIGH STREET',
#   'number': 7,
#   'position': {'lat': 53.343565, 'lng': -6.275071},
#   'status': 'OPEN'},
#  {'address': 'North Circular Road',
#   'available_bike_stands': 23,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679922000,
#   'name': 'NORTH CIRCULAR ROAD',
#   'number': 60,
#   'position': {'lat': 53.359624, 'lng': -6.260348},
#   'status': 'OPEN'},
#  {'address': 'Western Way',
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679959000,
#   'name': 'WESTERN WAY',
#   'number': 102,
#   'position': {'lat': 53.354929, 'lng': -6.269425},
#   'status': 'OPEN'},
#  {'address': 'Talbot Street',
#   'available_bike_stands': 33,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679786000,
#   'name': 'TALBOT STREET',
#   'number': 38,
#   'position': {'lat': 53.350974, 'lng': -6.25294},
#   'status': 'OPEN'},
#  {'address': 'Newman House',
#   'available_bike_stands': 19,
#   'available_bikes': 21,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680173000,
#   'name': 'NEWMAN HOUSE',
#   'number': 53,
#   'position': {'lat': 53.337132, 'lng': -6.26059},
#   'status': 'OPEN'},
#  {'address': "Sir Patrick's Dun",
#   'available_bike_stands': 21,
#   'available_bikes': 19,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680193000,
#   'name': "SIR PATRICK DUN'S",
#   'number': 58,
#   'position': {'lat': 53.339218, 'lng': -6.240642},
#   'status': 'OPEN'},
#  {'address': 'New Central Bank',
#   'available_bike_stands': 5,
#   'available_bikes': 35,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680237000,
#   'name': 'NEW CENTRAL BANK',
#   'number': 66,
#   'position': {'lat': 53.347122, 'lng': -6.234749},
#   'status': 'OPEN'},
#  {'address': 'Grangegorman Lower (Central)',
#   'available_bike_stands': 34,
#   'available_bikes': 6,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680231000,
#   'name': 'GRANGEGORMAN LOWER (CENTRAL)',
#   'number': 104,
#   'position': {'lat': 53.355173, 'lng': -6.278424},
#   'status': 'OPEN'},
#  {'address': 'King Street North',
#   'available_bike_stands': 28,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680083000,
#   'name': 'KING STREET NORTH',
#   'number': 101,
#   'position': {'lat': 53.350291, 'lng': -6.273507},
#   'status': 'OPEN'},
#  {'address': 'Killarney Street',
#   'available_bike_stands': 28,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680229000,
#   'name': 'KILLARNEY STREET',
#   'number': 115,
#   'position': {'lat': 53.354845, 'lng': -6.247579},
#   'status': 'OPEN'},
#  {'address': 'Herbert Street',
#   'available_bike_stands': 7,
#   'available_bikes': 32,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680124000,
#   'name': 'HERBERT STREET',
#   'number': 47,
#   'position': {'lat': 53.335742, 'lng': -6.24551},
#   'status': 'OPEN'},
#  {'address': 'Custom House Quay',
#   'available_bike_stands': 11,
#   'available_bikes': 19,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680201000,
#   'name': 'CUSTOM HOUSE QUAY',
#   'number': 8,
#   'position': {'lat': 53.347884, 'lng': -6.248048},
#   'status': 'OPEN'},
#  {'address': 'Molesworth Street',
#   'available_bike_stands': 15,
#   'available_bikes': 5,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679920000,
#   'name': 'MOLESWORTH STREET',
#   'number': 27,
#   'position': {'lat': 53.341288, 'lng': -6.258117},
#   'status': 'OPEN'},
#  {'address': 'Georges Quay',
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679893000,
#   'name': 'GEORGES QUAY',
#   'number': 16,
#   'position': {'lat': 53.347508, 'lng': -6.252192},
#   'status': 'OPEN'},
#  {'address': 'Kilmainham Lane',
#   'available_bike_stands': 29,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679783000,
#   'name': 'KILMAINHAM LANE',
#   'number': 96,
#   'position': {'lat': 53.341805, 'lng': -6.305085},
#   'status': 'OPEN'},
#  {'address': 'Mount Brown',
#   'available_bike_stands': 22,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 22,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679665000,
#   'name': 'MOUNT BROWN',
#   'number': 82,
#   'position': {'lat': 53.341645, 'lng': -6.29719},
#   'status': 'OPEN'},
#  {'address': 'Market Street South',
#   'available_bike_stands': 33,
#   'available_bikes': 5,
#   'banking': False,
#   'bike_stands': 38,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680033000,
#   'name': 'MARKET STREET SOUTH',
#   'number': 76,
#   'position': {'lat': 53.342296, 'lng': -6.287661},
#   'status': 'OPEN'},
#  {'address': 'Kevin Street',
#   'available_bike_stands': 33,
#   'available_bikes': 7,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680237000,
#   'name': 'KEVIN STREET',
#   'number': 71,
#   'position': {'lat': 53.337757, 'lng': -6.267699},
#   'status': 'OPEN'},
#  {'address': 'Eccles Street East',
#   'available_bike_stands': 27,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 27,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679911000,
#   'name': 'ECCLES STREET EAST',
#   'number': 79,
#   'position': {'lat': 53.358115, 'lng': -6.265601},
#   'status': 'OPEN'},
#  {'address': 'Grand Canal Dock',
#   'available_bike_stands': 4,
#   'available_bikes': 36,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679991000,
#   'name': 'GRAND CANAL DOCK',
#   'number': 69,
#   'position': {'lat': 53.342638, 'lng': -6.238695},
#   'status': 'OPEN'},
#  {'address': 'Merrion Square East',
#   'available_bike_stands': 9,
#   'available_bikes': 21,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679729000,
#   'name': 'MERRION SQUARE EAST',
#   'number': 25,
#   'position': {'lat': 53.339434, 'lng': -6.246548},
#   'status': 'OPEN'},
#  {'address': 'York Street West',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679880000,
#   'name': 'YORK STREET WEST',
#   'number': 51,
#   'position': {'lat': 53.339334, 'lng': -6.264699},
#   'status': 'OPEN'},
#  {'address': "St. Stephen's Green South",
#   'available_bike_stands': 21,
#   'available_bikes': 9,
#   'banking': True,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680123000,
#   'name': "ST. STEPHEN'S GREEN SOUTH",
#   'number': 37,
#   'position': {'lat': 53.337494, 'lng': -6.26199},
#   'status': 'OPEN'},
#  {'address': 'Denmark Street Great',
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680041000,
#   'name': 'DENMARK STREET GREAT',
#   'number': 59,
#   'position': {'lat': 53.35561, 'lng': -6.261397},
#   'status': 'OPEN'},
#  {'address': 'Royal Hospital',
#   'available_bike_stands': 27,
#   'available_bikes': 12,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680261000,
#   'name': 'ROYAL HOSPITAL',
#   'number': 95,
#   'position': {'lat': 53.343897, 'lng': -6.29706},
#   'status': 'OPEN'},
#  {'address': 'Heuston Station (Car Park)',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679843000,
#   'name': 'HEUSTON STATION (CAR PARK)',
#   'number': 94,
#   'position': {'lat': 53.346985, 'lng': -6.297804},
#   'status': 'OPEN'},
#  {'address': 'Grangegorman Lower (North)',
#   'available_bike_stands': 36,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 36,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679871000,
#   'name': 'GRANGEGORMAN LOWER (NORTH)',
#   'number': 105,
#   'position': {'lat': 53.355954, 'lng': -6.278378},
#   'status': 'OPEN'},
#  {'address': "St. Stephen's Green East",
#   'available_bike_stands': 20,
#   'available_bikes': 20,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680256000,
#   'name': "ST. STEPHEN'S GREEN EAST",
#   'number': 36,
#   'position': {'lat': 53.337824, 'lng': -6.256035},
#   'status': 'OPEN'},
#  {'address': 'Heuston Station (Central)',
#   'available_bike_stands': 28,
#   'available_bikes': 12,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680230000,
#   'name': 'HEUSTON STATION (CENTRAL)',
#   'number': 93,
#   'position': {'lat': 53.346603, 'lng': -6.296924},
#   'status': 'OPEN'},
#  {'address': 'Townsend Street',
#   'available_bike_stands': 15,
#   'available_bikes': 5,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680256000,
#   'name': 'TOWNSEND STREET',
#   'number': 22,
#   'position': {'lat': 53.345922, 'lng': -6.254614},
#   'status': 'OPEN'},
#  {'address': "George's Lane",
#   'available_bike_stands': 33,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680253000,
#   'name': 'GEORGES LANE',
#   'number': 50,
#   'position': {'lat': 53.35023, 'lng': -6.279696},
#   'status': 'OPEN'},
#  {'address': 'Phibsborough Road',
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680243000,
#   'name': 'PHIBSBOROUGH ROAD',
#   'number': 110,
#   'position': {'lat': 53.356307, 'lng': -6.273717},
#   'status': 'OPEN'},
#  {'address': 'Eccles Street',
#   'available_bike_stands': 12,
#   'available_bikes': 8,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679944000,
#   'name': 'ECCLES STREET',
#   'number': 12,
#   'position': {'lat': 53.359246, 'lng': -6.269779},
#   'status': 'OPEN'},
#  {'address': 'Portobello Harbour',
#   'available_bike_stands': 23,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680136000,
#   'name': 'PORTOBELLO HARBOUR',
#   'number': 34,
#   'position': {'lat': 53.330362, 'lng': -6.265163},
#   'status': 'OPEN'},
#  {'address': 'Mater Hospital',
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680041000,
#   'name': 'MATER HOSPITAL',
#   'number': 78,
#   'position': {'lat': 53.359967, 'lng': -6.264828},
#   'status': 'OPEN'},
#  {'address': 'Blessington Street',
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679685000,
#   'name': 'BLESSINGTON STREET',
#   'number': 2,
#   'position': {'lat': 53.356769, 'lng': -6.26814},
#   'status': 'OPEN'},
#  {'address': 'James Street',
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680153000,
#   'name': 'JAMES STREET',
#   'number': 75,
#   'position': {'lat': 53.343456, 'lng': -6.287409},
#   'status': 'OPEN'},
#  {'address': 'Mountjoy Square East',
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679737000,
#   'name': 'MOUNTJOY SQUARE EAST',
#   'number': 111,
#   'position': {'lat': 53.356717, 'lng': -6.256359},
#   'status': 'OPEN'},
#  {'address': 'Merrion Square West',
#   'available_bike_stands': 9,
#   'available_bikes': 11,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680119000,
#   'name': 'MERRION SQUARE WEST',
#   'number': 26,
#   'position': {'lat': 53.339764, 'lng': -6.251988},
#   'status': 'OPEN'},
#  {'address': 'Convention Centre',
#   'available_bike_stands': 7,
#   'available_bikes': 33,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679928000,
#   'name': 'CONVENTION CENTRE',
#   'number': 65,
#   'position': {'lat': 53.34744, 'lng': -6.238523},
#   'status': 'OPEN'},
#  {'address': 'Hardwicke Street',
#   'available_bike_stands': 16,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 16,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679682000,
#   'name': 'HARDWICKE STREET',
#   'number': 15,
#   'position': {'lat': 53.355473, 'lng': -6.264423},
#   'status': 'OPEN'},
#  {'address': 'Parkgate Street',
#   'available_bike_stands': 30,
#   'available_bikes': 7,
#   'banking': True,
#   'bike_stands': 38,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680135000,
#   'name': 'PARKGATE STREET',
#   'number': 86,
#   'position': {'lat': 53.347972, 'lng': -6.291804},
#   'status': 'OPEN'},
#  {'address': 'Smithfield',
#   'available_bike_stands': 22,
#   'available_bikes': 8,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680002000,
#   'name': 'SMITHFIELD',
#   'number': 35,
#   'position': {'lat': 53.347692, 'lng': -6.278214},
#   'status': 'OPEN'},
#  {'address': 'Dame Street',
#   'available_bike_stands': 14,
#   'available_bikes': 2,
#   'banking': True,
#   'bike_stands': 16,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680180000,
#   'name': 'DAME STREET',
#   'number': 10,
#   'position': {'lat': 53.344007, 'lng': -6.266802},
#   'status': 'OPEN'},
#  {'address': 'Heuston Bridge (South)',
#   'available_bike_stands': 1,
#   'available_bikes': 24,
#   'banking': False,
#   'bike_stands': 25,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680167000,
#   'name': 'HEUSTON BRIDGE (SOUTH)',
#   'number': 100,
#   'position': {'lat': 53.347106, 'lng': -6.292041},
#   'status': 'OPEN'},
#  {'address': 'Cathal Brugha Street',
#   'available_bike_stands': 13,
#   'available_bikes': 7,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680235000,
#   'name': 'CATHAL BRUGHA STREET',
#   'number': 24,
#   'position': {'lat': 53.352149, 'lng': -6.260533},
#   'status': 'OPEN'},
#  {'address': 'Sandwith Street',
#   'available_bike_stands': 16,
#   'available_bikes': 24,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679946000,
#   'name': 'SANDWITH STREET',
#   'number': 64,
#   'position': {'lat': 53.345203, 'lng': -6.247163},
#   'status': 'OPEN'},
#  {'address': 'Buckingham Street Lower',
#   'available_bike_stands': 28,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 29,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679925000,
#   'name': 'BUCKINGHAM STREET LOWER',
#   'number': 109,
#   'position': {'lat': 53.353331, 'lng': -6.249319},
#   'status': 'OPEN'},
#  {'address': 'Rothe Abbey',
#   'available_bike_stands': 29,
#   'available_bikes': 6,
#   'banking': True,
#   'bike_stands': 35,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680184000,
#   'name': 'ROTHE ABBEY',
#   'number': 85,
#   'position': {'lat': 53.338776, 'lng': -6.30395},
#   'status': 'OPEN'},
#  {'address': 'Charleville Road',
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680097000,
#   'name': 'CHARLEVILLE ROAD',
#   'number': 107,
#   'position': {'lat': 53.359157, 'lng': -6.281866},
#   'status': 'OPEN'},
#  {'address': "Princes Street / O'Connell Street",
#   'available_bike_stands': 0,
#   'available_bikes': 23,
#   'banking': True,
#   'bike_stands': 23,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679995000,
#   'name': "PRINCES STREET / O'CONNELL STREET",
#   'number': 33,
#   'position': {'lat': 53.349013, 'lng': -6.260311},
#   'status': 'OPEN'},
#  {'address': 'Upper Sherrard Street',
#   'available_bike_stands': 18,
#   'available_bikes': 12,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680185000,
#   'name': 'UPPER SHERRARD STREET',
#   'number': 44,
#   'position': {'lat': 53.358437, 'lng': -6.260641},
#   'status': 'OPEN'},
#  {'address': 'Fitzwilliam Square East',
#   'available_bike_stands': 21,
#   'available_bikes': 19,
#   'banking': True,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680113000,
#   'name': 'FITZWILLIAM SQUARE EAST',
#   'number': 89,
#   'position': {'lat': 53.335211, 'lng': -6.2509},
#   'status': 'OPEN'},
#  {'address': 'Grattan Street',
#   'available_bike_stands': 1,
#   'available_bikes': 22,
#   'banking': False,
#   'bike_stands': 23,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679721000,
#   'name': 'GRATTAN STREET',
#   'number': 57,
#   'position': {'lat': 53.339629, 'lng': -6.243778},
#   'status': 'OPEN'},
#  {'address': 'St James Hospital (Luas)',
#   'available_bike_stands': 29,
#   'available_bikes': 11,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679849000,
#   'name': 'ST JAMES HOSPITAL (LUAS)',
#   'number': 80,
#   'position': {'lat': 53.341359, 'lng': -6.292951},
#   'status': 'OPEN'},
#  {'address': 'Harcourt Terrace',
#   'available_bike_stands': 18,
#   'available_bikes': 2,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680223000,
#   'name': 'HARCOURT TERRACE',
#   'number': 41,
#   'position': {'lat': 53.332763, 'lng': -6.257942},
#   'status': 'OPEN'},
#  {'address': 'Bolton Street',
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680066000,
#   'name': 'BOLTON STREET',
#   'number': 3,
#   'position': {'lat': 53.351182, 'lng': -6.269859},
#   'status': 'OPEN'},
#  {'address': 'Strand Street Great',
#   'available_bike_stands': 15,
#   'available_bikes': 4,
#   'banking': True,
#   'bike_stands': 35,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679812000,
#   'name': 'STRAND STREET GREAT',
#   'number': 46,
#   'position': {'lat': 53.347082, 'lng': -6.264192},
#   'status': 'OPEN'},
#  {'address': 'Jervis Street',
#   'available_bike_stands': 21,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 21,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679728000,
#   'name': 'JERVIS STREET',
#   'number': 40,
#   'position': {'lat': 53.3483, 'lng': -6.266651},
#   'status': 'OPEN'},
#  {'address': 'Ormond Quay Upper',
#   'available_bike_stands': 29,
#   'available_bikes': 0,
#   'banking': True,
#   'bike_stands': 29,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680122000,
#   'name': 'ORMOND QUAY UPPER',
#   'number': 29,
#   'position': {'lat': 53.346057, 'lng': -6.268001},
#   'status': 'OPEN'},
#  {'address': 'Barrow Street',
#   'available_bike_stands': 16,
#   'available_bikes': 11,
#   'banking': True,
#   'bike_stands': 28,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680142000,
#   'name': 'BARROW STREET',
#   'number': 70,
#   'position': {'lat': 53.341655, 'lng': -6.236198},
#   'status': 'OPEN'},
#  {'address': 'Grangegorman Lower (South)',
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680147000,
#   'name': 'GRANGEGORMAN LOWER (SOUTH)',
#   'number': 103,
#   'position': {'lat': 53.354663, 'lng': -6.278681},
#   'status': 'OPEN'},
#  {'address': 'Mountjoy Square West',
#   'available_bike_stands': 29,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680256000,
#   'name': 'MOUNTJOY SQUARE WEST',
#   'number': 28,
#   'position': {'lat': 53.356299, 'lng': -6.258586},
#   'status': 'OPEN'},
#  {'address': 'Wilton Terrace',
#   'available_bike_stands': 12,
#   'available_bikes': 8,
#   'banking': True,
#   'bike_stands': 20,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680249000,
#   'name': 'WILTON TERRACE',
#   'number': 39,
#   'position': {'lat': 53.332383, 'lng': -6.252717},
#   'status': 'OPEN'},
#  {'address': 'Emmet Road',
#   'available_bike_stands': 34,
#   'available_bikes': 6,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679877000,
#   'name': 'EMMET ROAD',
#   'number': 83,
#   'position': {'lat': 53.340714, 'lng': -6.308191},
#   'status': 'OPEN'},
#  {'address': 'Heuston Bridge (North)',
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'banking': False,
#   'bike_stands': 40,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680206000,
#   'name': 'HEUSTON BRIDGE (NORTH)',
#   'number': 92,
#   'position': {'lat': 53.347802, 'lng': -6.292432},
#   'status': 'OPEN'},
#  {'address': 'Leinster Street South',
#   'available_bike_stands': 14,
#   'available_bikes': 16,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550679998000,
#   'name': 'LEINSTER STREET SOUTH',
#   'number': 21,
#   'position': {'lat': 53.34218, 'lng': -6.254485},
#   'status': 'OPEN'},
#  {'address': 'Blackhall Place',
#   'available_bike_stands': 26,
#   'available_bikes': 4,
#   'banking': False,
#   'bike_stands': 30,
#   'bonus': False,
#   'contract_name': 'Dublin',
#   'last_update': 1550680233000,
#   'name': 'BLACKHALL PLACE',
#   'number': 88,
#   'position': {'lat': 53.3488, 'lng': -6.281637},
#   'status': 'OPEN'}]

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello():
    return 'Hello, World!'

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Feb/2019 10:18:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2019 10:18:39] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [21/Feb/2019 10:19:11] "GET / HTTP/1.1" 200 -
